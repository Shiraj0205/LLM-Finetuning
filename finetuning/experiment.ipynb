# %%
# !pip install cmake==3.27.0 pyarrow==16.1.0 datasets transformers accelerate sagemaker boto3 --upgrade --no-cache-dir

# %%
import boto3

# %%
s3=boto3.client("s3")

# %%
response = s3.list_objects_v2(Bucket="llm-finetune-dataset-sh", Prefix="datasets/")
# Out:
# ---------------------------------------------------------------------------
# NoCredentialsError                        Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 response = s3.list_objects_v2(Bucket="llm-finetune-dataset-sh", Prefix="datasets/")
#
# File d:\Data\Projects\LLM-Finetuning\venv\Lib\site-packages\botocore\client.py:602, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     598     raise TypeError(
#     599         f"{py_operation_name}() only accepts keyword arguments."
#     600     )
#     601 # The "self" in this scope is referring to the BaseClient.
# --> 602 return self._make_api_call(operation_name, kwargs)
#
# File d:\Data\Projects\LLM-Finetuning\venv\Lib\site-packages\botocore\context.py:123, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     121 if hook:
#     122     hook()
# --> 123 return func(*args, **kwargs)
#
# ...

# %%
for obj in response.get("Contents", []):
    print(obj)
# Out:
# {'Key': 'datasets/', 'LastModified': datetime.datetime(2025, 11, 9, 9, 41, 6, tzinfo=tzlocal()), 'ETag': '"d41d8cd98f00b204e9800998ecf8427e"', 'ChecksumAlgorithm': ['CRC64NVME'], 'ChecksumType': 'FULL_OBJECT', 'Size': 0, 'StorageClass': 'STANDARD'}
# {'Key': 'datasets/pharma_instruction_data.csv', 'LastModified': datetime.datetime(2025, 11, 9, 10, 35, 6, tzinfo=tzlocal()), 'ETag': '"7a3bbfb7acae4d8dc88dc1a08501d745"', 'ChecksumAlgorithm': ['CRC64NVME'], 'ChecksumType': 'FULL_OBJECT', 'Size': 2469, 'StorageClass': 'STANDARD'}

# %%
for obj in response.get("Contents", []):
    print(obj["Key"])
# Out:
# datasets/
# datasets/pharma_instruction_data.csv

# %%
# !which python
# Out:
# /home/ec2-user/anaconda3/envs/python3/bin/python

# %%
dataset_path = "s3://llm-finetune-dataset-sunny/datasets/pharma_instruction_data.csv/"

# %%
from datasets import load_dataset

# %%
dataset = load_dataset("csv",data_files={"train":dataset_path})
# Out:
# ...
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['instruction', 'input', 'output'],
#         num_rows: 5
#     })
# })

# %%
print(dataset["train"])
# Out:
# Dataset({
#     features: ['instruction', 'input', 'output'],
#     num_rows: 5
# })

# %%
print(dataset["train"][0])
# Out:
# {'instruction': 'Explain the mechanism of action of Metformin.', 'input': None, 'output': 'Metformin activates AMP-activated protein kinase (AMPK), which increases glucose uptake and fatty-acid oxidation while inhibiting hepatic gluconeogenesis, thereby lowering blood glucose.'}
